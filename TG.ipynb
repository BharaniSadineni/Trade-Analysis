# %%
import pandas as pd

# Define the correct file path
file_path = "E:/UE Sose2024/Projects/Data Science and Business/Assignment/XL partners all/Partners all 2023-2017 XL.xlsx"

# Load the Excel file
data = pd.read_excel(file_path)

# Display the first few rows of the DataFrame
data.head()
# Out:
#   TypeCode FreqCode  RefPeriodId  RefYear  RefMonth  Period  ReporterCode  \
# 0        C        A     20170101     2017        52    2017           716
# 1        C        A     20170101     2017        52    2017           716
# 2        C        A     20170101     2017        52    2017           716
# 3        C        A     20170101     2017        52    2017           716
# 4        C        A     20170101     2017        52    2017           716
#
#   ReporterISO ReporterDesc FlowCode  ...     NetWgt  IsNetWgtEstimated  \
# 0         ZWE     Zimbabwe        X  ...  21900.023              False
# 1         ZWE     Zimbabwe        X  ...  17164.583              False
# 2         ZWE     Zimbabwe        X  ...   4735.440              False
# 3         ZWE     Zimbabwe        X  ...        NaN              False
# 4         ZWE     Zimbabwe        X  ...        NaN              False
#
#   GrossWgt IsGrossWgtEstimated  Cifvalue      Fobvalue  PrimaryValue  \
# ...

# %%
import pandas as pd

# Define the correct file path
file_path = "E:/UE Sose2024/Projects/Data Science and Business/Assignment/XL partners all/Partners all 2023-2017 XL.xlsx"

# List of columns to read
columns_to_read = [
    'Period', 'ReporterDesc', 'PartnerDesc', 'CmdCode', 'QtyUnitAbbr',
    'Qty', 'AltQtyUnitAbbr', 'AltQty', 'NetWgt', 'PrimaryValue'
]


# Load the specified columns from the Excel file
data = pd.read_excel(file_path, usecols=columns_to_read)

# Display the first few rows of the DataFrame
data.head()
# Out:
#    Period ReporterDesc           PartnerDesc  CmdCode QtyUnitAbbr        Qty  \
# 0    2017     Zimbabwe                 World     7108          kg  21900.023
# 1    2017     Zimbabwe          South Africa     7108          kg  17164.583
# 2    2017     Zimbabwe  United Arab Emirates     7108          kg   4735.440
# 3    2017     Zimbabwe                 World   710812          kg      0.123
# 4    2017     Zimbabwe          South Africa   710812          kg      0.123
#
#   AltQtyUnitAbbr  AltQty     NetWgt  PrimaryValue
# 0              g  2061.0  21900.023  8.860256e+08
# 1              g  1515.0  17164.583  6.919713e+08
# 2              g   546.0   4735.440  1.940542e+08
# 3              g   123.0        NaN  1.000000e+02
# 4              g   123.0        NaN  1.000000e+02

# %%
import pandas as pd

# Define the correct file path
file_path = "E:/UE Sose2024/Projects/Data Science and Business/Assignment/XL partners all/Partners all 2023-2017 XL.xlsx"

# List of columns to read
columns_to_read = [
    'Period', 'ReporterDesc', 'PartnerDesc', 'CmdCode', 'QtyUnitAbbr',
    'Qty', 'AltQtyUnitAbbr', 'AltQty', 'NetWgt', 'PrimaryValue'
]


# Load the specified columns from the Excel file
data = pd.read_excel(file_path, usecols=columns_to_read)

# Display the first few rows of the DataFrame
total_rows = data.shape[0]
print(f"\nTotal number of rows: {total_rows}")
# Out:
# Total number of rows: 89

# %%
import pandas as pd

# Define the correct file path
file_path = "E:/UE Sose2024/Projects/Data Science and Business/Assignment/XL partners all/Partners all 2023-2017 XL.xlsx"

# List of columns to read
columns_to_read = [
    'Period', 'ReporterDesc', 'PartnerDesc', 'CmdCode', 'QtyUnitAbbr',
    'Qty', 'AltQtyUnitAbbr', 'AltQty', 'NetWgt', 'PrimaryValue'
]


# Load the specified columns from the Excel file
data = pd.read_excel(file_path, usecols=columns_to_read)

total_rows = data.shape[0]
print(f"\nTotal number of rows: {total_rows}")

# Set pandas display option to show all rows
pd.set_option('display.max_rows', total_rows)
pd.set_option('display.max_columns', None)

# Display all rows of the DataFrame in a table format
print(data.to_string(index=False))
# Out:
# Total number of rows: 89
#  Period ReporterDesc          PartnerDesc  CmdCode QtyUnitAbbr       Qty AltQtyUnitAbbr      AltQty    NetWgt  PrimaryValue
#    2017     Zimbabwe                World     7108          kg 21900.023              g     2061.00 21900.023  8.860256e+08
#    2017     Zimbabwe         South Africa     7108          kg 17164.583              g     1515.00 17164.583  6.919713e+08
#    2017     Zimbabwe United Arab Emirates     7108          kg  4735.440              g      546.00  4735.440  1.940542e+08
#    2017     Zimbabwe                World   710812          kg     0.123              g      123.00       NaN  1.000000e+02
#    2017     Zimbabwe         South Africa   710812          kg     0.123              g      123.00       NaN  1.000000e+02
#    2017     Zimbabwe                World   710813          kg 21899.900              g     1938.00 21899.900  8.860255e+08
# ...

# %%
import pandas as pd

# Define the correct file path
file_path = "E:/UE Sose2024/Projects/Data Science and Business/Assignment/XL partners all/Partners all 2023-2017 XL.xlsx"

# List of columns to read
columns_to_read = [
    'Period', 'ReporterDesc', 'PartnerDesc', 'CmdCode', 'QtyUnitAbbr',
    'Qty', 'AltQtyUnitAbbr', 'AltQty', 'NetWgt', 'PrimaryValue'
]


# Load the specified columns from the Excel file
data = pd.read_excel(file_path, usecols=columns_to_read)

# Sort the DataFrame by 'ReporterDesc'
sorted_data = data.sort_values(by=['ReporterDesc', 'Period', 'CmdCode'])

# Display the total number of rows
total_rows = sorted_data.shape[0]
print(f"\nTotal number of rows: {total_rows}")

# Set pandas display option to show all rows
pd.set_option('display.max_rows', total_rows)
pd.set_option('display.max_columns', None)

# Display all rows of the sorted DataFrame in a table format
print(sorted_data.to_string(index=False))
# Out:
# Total number of rows: 89
#  Period ReporterDesc          PartnerDesc  CmdCode QtyUnitAbbr       Qty AltQtyUnitAbbr      AltQty    NetWgt  PrimaryValue
#    2017         Togo                World     7108          kg 19957.000             kg    19957.00 19957.000  3.448247e+07
#    2017         Togo              Lebanon     7108          kg  4695.000             kg     4695.00  4695.000  8.115137e+06
#    2017         Togo United Arab Emirates     7108          kg 15262.000             kg    15262.00 15262.000  2.636734e+07
#    2017         Togo                World   710812          kg 19957.000             kg    19957.00 19957.000  3.448247e+07
#    2017         Togo              Lebanon   710812          kg  4695.000             kg     4695.00  4695.000  8.115137e+06
#    2017         Togo United Arab Emirates   710812          kg 15262.000             kg    15262.00 15262.000  2.636734e+07
# ...

# %%
import pandas as pd

# Define the correct file path
file_path = "E:/UE Sose2024/Projects/Data Science and Business/Assignment/XL partners all/Partners all 2023-2017 XL.xlsx"

# List of columns to read
columns_to_read = [
    'Period', 'ReporterDesc', 'PartnerDesc', 'CmdCode', 'QtyUnitAbbr',
    'Qty', 'AltQtyUnitAbbr', 'AltQty', 'NetWgt', 'PrimaryValue'
]


# Load the specified columns from the Excel file
data = pd.read_excel(file_path, usecols=columns_to_read)

# Sort the DataFrame by 'ReporterDesc'
sorted_data = data.sort_values(by=['ReporterDesc', 'Period', 'CmdCode',)



# Display the total number of rows
total_rows = sorted_data.shape[0]
print(f"\nTotal number of rows: {total_rows}")

# Set pandas display option to show all rows
pd.set_option('display.max_rows', total_rows)
pd.set_option('display.max_columns', None)

# Display all rows of the sorted DataFrame in a table format
print(sorted_data.to_string(index=False))
# Out:
# Total number of rows: 89
#  Period ReporterDesc          PartnerDesc  CmdCode QtyUnitAbbr       Qty AltQtyUnitAbbr      AltQty    NetWgt  PrimaryValue
#    2017         Togo              Lebanon     7108          kg  4695.000             kg     4695.00  4695.000  8.115137e+06
#    2017         Togo United Arab Emirates     7108          kg 15262.000             kg    15262.00 15262.000  2.636734e+07
#    2017         Togo                World     7108          kg 19957.000             kg    19957.00 19957.000  3.448247e+07
#    2017         Togo              Lebanon   710812          kg  4695.000             kg     4695.00  4695.000  8.115137e+06
#    2017         Togo United Arab Emirates   710812          kg 15262.000             kg    15262.00 15262.000  2.636734e+07
#    2017         Togo                World   710812          kg 19957.000             kg    19957.00 19957.000  3.448247e+07
# ...

# %%
import pandas as pd

# Define the correct file path
file_path = "E:/UE Sose2024/Projects/Data Science and Business/Assignment/XL partners all/Partners all 2023-2017 XL.xlsx"

# List of columns to read
columns_to_read = [
    'Period', 'ReporterDesc', 'PartnerDesc', 'CmdCode', 'QtyUnitAbbr',
    'Qty', 'AltQtyUnitAbbr', 'AltQty', 'NetWgt', 'PrimaryValue'
]

# Load the specified columns from the Excel file
data = pd.read_excel(file_path, usecols=columns_to_read)

# Convert AltQty from grams to kilograms where AltQtyUnitAbbr is 'g'
mask = data['AltQtyUnitAbbr'] == 'g'
data.loc[mask, 'AltQty'] = data.loc[mask, 'AltQty'] / 1000
data.loc[mask, 'AltQtyUnitAbbr'] = 'kg'

# Sort the DataFrame by ReporterDesc, Period, and CmdCode
sorted_data = data.sort_values(by=['ReporterDesc', 'Period', 'CmdCode','PartnerDesc'])

# Display the total number of rows
total_rows = sorted_data.shape[0]
print(f"\nTotal number of rows: {total_rows}")

# Set pandas display option to show all rows
pd.set_option('display.max_rows', total_rows)
pd.set_option('display.max_columns', None)

# Display all rows of the sorted DataFrame in a table format
print(sorted_data.to_string(index=False))
# Out:
# Total number of rows: 89
#  Period ReporterDesc          PartnerDesc  CmdCode QtyUnitAbbr       Qty AltQtyUnitAbbr      AltQty    NetWgt  PrimaryValue
#    2017         Togo              Lebanon     7108          kg  4695.000             kg  4695.00000  4695.000  8.115137e+06
#    2017         Togo United Arab Emirates     7108          kg 15262.000             kg 15262.00000 15262.000  2.636734e+07
#    2017         Togo                World     7108          kg 19957.000             kg 19957.00000 19957.000  3.448247e+07
#    2017         Togo              Lebanon   710812          kg  4695.000             kg  4695.00000  4695.000  8.115137e+06
#    2017         Togo United Arab Emirates   710812          kg 15262.000             kg 15262.00000 15262.000  2.636734e+07
#    2017         Togo                World   710812          kg 19957.000             kg 19957.00000 19957.000  3.448247e+07
# ...

# %%
import pandas as pd

# Define the correct file path
file_path = "E:/UE Sose2024/Projects/Data Science and Business/Assignment/XL partners all/Partners all 2023-2017 XL.xlsx"

# List of columns to read
columns_to_read = [
    'Period', 'ReporterDesc', 'PartnerDesc', 'CmdCode', 'QtyUnitAbbr',
    'Qty', 'AltQtyUnitAbbr', 'AltQty', 'NetWgt', 'PrimaryValue'
]

# Load the specified columns from the Excel file
data = pd.read_excel(file_path, usecols=columns_to_read)

# Convert AltQty from grams to kilograms where AltQtyUnitAbbr is 'g'
mask = data['AltQtyUnitAbbr'] == 'g'
data.loc[mask, 'AltQty'] = data.loc[mask, 'AltQty'] / 1000
data.loc[mask, 'AltQtyUnitAbbr'] = 'kg'

# Sort the DataFrame by ReporterDesc, Period, CmdCode, and PartnerDesc
sorted_data = data.sort_values(by=['ReporterDesc', 'Period', 'CmdCode', 'PartnerDesc'])

# Remove the QtyUnitAbbr and AltQtyUnitAbbr columns
sorted_data = sorted_data.drop(columns=['QtyUnitAbbr', 'AltQtyUnitAbbr'])

# Display the total number of rows
total_rows = sorted_data.shape[0]
print(f"\nTotal number of rows: {total_rows}")

# Set pandas display option to show all rows
pd.set_option('display.max_rows', total_rows)
pd.set_option('display.max_columns', None)

# Display all rows of the sorted DataFrame in a table format
print(sorted_data.to_string(index=False))
# Out:
# Total number of rows: 89
#  Period ReporterDesc          PartnerDesc  CmdCode       Qty      AltQty    NetWgt  PrimaryValue
#    2017         Togo              Lebanon     7108  4695.000  4695.00000  4695.000  8.115137e+06
#    2017         Togo United Arab Emirates     7108 15262.000 15262.00000 15262.000  2.636734e+07
#    2017         Togo                World     7108 19957.000 19957.00000 19957.000  3.448247e+07
#    2017         Togo              Lebanon   710812  4695.000  4695.00000  4695.000  8.115137e+06
#    2017         Togo United Arab Emirates   710812 15262.000 15262.00000 15262.000  2.636734e+07
#    2017         Togo                World   710812 19957.000 19957.00000 19957.000  3.448247e+07
#    2018         Togo              Belgium     7108   205.000   205.00000   205.000  3.720026e+05
#    2018         Togo              Lebanon     7108  2791.000  2791.00000  2791.000  5.060928e+06
# ...

# %%
import pandas as pd

# Define the correct file path
file_path = "E:/UE Sose2024/Projects/Data Science and Business/Assignment/XL partners all/Partners all 2023-2017 XL.xlsx"

# List of columns to read
columns_to_read = [
    'Period', 'ReporterDesc', 'PartnerDesc', 'CmdCode', 'QtyUnitAbbr',
    'Qty', 'AltQtyUnitAbbr', 'AltQty', 'NetWgt', 'PrimaryValue'
]

# Load the specified columns from the Excel file
data = pd.read_excel(file_path, usecols=columns_to_read)

# Convert AltQty from grams to kilograms where AltQtyUnitAbbr is 'g'
mask = data['AltQtyUnitAbbr'] == 'g'
data.loc[mask, 'AltQty'] = data.loc[mask, 'AltQty'] / 1000
data.loc[mask, 'AltQtyUnitAbbr'] = 'kg'

# Convert PrimaryValue to millions
data['PrimaryValue'] = data['PrimaryValue'] / 1e6

# Sort the DataFrame by ReporterDesc, Period, CmdCode, and PartnerDesc
sorted_data = data.sort_values(by=['ReporterDesc', 'Period', 'CmdCode', 'PartnerDesc'])

# Remove the QtyUnitAbbr and AltQtyUnitAbbr columns
sorted_data = sorted_data.drop(columns=['QtyUnitAbbr', 'AltQtyUnitAbbr'])

# Rename the PrimaryValue column to indicate the unit is in millions
sorted_data = sorted_data.rename(columns={'PrimaryValue': 'PrimaryValue (millions)'})

# Display the total number of rows
total_rows = sorted_data.shape[0]
print(f"\nTotal number of rows: {total_rows}")

# Set pandas display option to show all rows
pd.set_option('display.max_rows', total_rows)
pd.set_option('display.max_columns', None)

# Display all rows of the sorted DataFrame in a table format
print(sorted_data.to_string(index=False))
# Out:
# Total number of rows: 89
#  Period ReporterDesc          PartnerDesc  CmdCode       Qty      AltQty    NetWgt  PrimaryValue (millions)
#    2017         Togo              Lebanon     7108  4695.000  4695.00000  4695.000                 8.115137
#    2017         Togo United Arab Emirates     7108 15262.000 15262.00000 15262.000                26.367337
#    2017         Togo                World     7108 19957.000 19957.00000 19957.000                34.482474
#    2017         Togo              Lebanon   710812  4695.000  4695.00000  4695.000                 8.115137
#    2017         Togo United Arab Emirates   710812 15262.000 15262.00000 15262.000                26.367337
#    2017         Togo                World   710812 19957.000 19957.00000 19957.000                34.482474
#    2018         Togo              Belgium     7108   205.000   205.00000   205.000                 0.372003
# ...

# %%
import pandas as pd

# Define the correct file path
file_path = "E:/UE Sose2024/Projects/Data Science and Business/Assignment/XL partners all/Partners all 2023-2017 XL.xlsx"

# List of columns to read
columns_to_read = [
    'Period', 'ReporterDesc', 'PartnerDesc', 'CmdCode', 'QtyUnitAbbr',
    'Qty', 'AltQtyUnitAbbr', 'AltQty', 'NetWgt', 'PrimaryValue'
]

# Load the specified columns from the Excel file
data = pd.read_excel(file_path, usecols=columns_to_read)

# Convert AltQty from grams to kilograms where AltQtyUnitAbbr is 'g'
mask = data['AltQtyUnitAbbr'] == 'g'
data.loc[mask, 'AltQty'] = data.loc[mask, 'AltQty'] / 1000
data.loc[mask, 'AltQtyUnitAbbr'] = 'kg'

# Convert PrimaryValue to millions
data['PrimaryValue'] = data['PrimaryValue'] / 1e6

# Sort the DataFrame by ReporterDesc, Period, CmdCode, and PartnerDesc
sorted_data = data.sort_values(by=['ReporterDesc', 'Period', 'CmdCode', 'PartnerDesc'])

# Remove the QtyUnitAbbr and AltQtyUnitAbbr columns
sorted_data = sorted_data.drop(columns=['QtyUnitAbbr', 'AltQtyUnitAbbr'])

# Rename the PrimaryValue column to indicate the unit is in millions
sorted_data = sorted_data.rename(columns={'PrimaryValue': 'PrimaryValue (millions)'})

# Display the total number of rows
total_rows = sorted_data.shape[0]
print(f"\nTotal number of rows: {total_rows}")

# Identify outliers in the PrimaryValue (millions) column
Q1 = sorted_data['PrimaryValue (millions)'].quantile(0.25)
Q3 = sorted_data['PrimaryValue (millions)'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = sorted_data[(sorted_data['PrimaryValue (millions)'] < lower_bound) | 
                       (sorted_data['PrimaryValue (millions)'] > upper_bound)]

print("\nOutliers in the PrimaryValue (millions) column:")
print(outliers)

# Optionally, you can save the outliers to a new Excel file
outliers_file_path = "E:/UE Sose2024/Projects/Data Science and Business/Assignment/XL partners all/Outliers.xlsx"
outliers.to_excel(outliers_file_path, index=False)
# Out:
# Total number of rows: 89
#
# Outliers in the PrimaryValue (millions) column:
#     Period ReporterDesc           PartnerDesc  CmdCode        Qty  \
# 74    2022     Zimbabwe  United Arab Emirates     7108  35531.070
# 71    2022     Zimbabwe                 World     7108  35706.178
# 78    2022     Zimbabwe  United Arab Emirates   710813  35531.070
# 75    2022     Zimbabwe                 World   710813  35706.178
# 81    2023     Zimbabwe  United Arab Emirates     7108  28943.860
# 79    2023     Zimbabwe                 World     7108      0.000
# 84    2023     Zimbabwe  United Arab Emirates   710813  28943.860
# 82    2023     Zimbabwe                 World   710813      0.000
#
#          AltQty    NetWgt  PrimaryValue (millions)
# 74  35531.07000  35668.12              1981.811101
# 71      0.00000       NaN              1992.346633
# 78  35531.07000  35668.12              1981.811101
# 75  35591.83629       NaN              1992.346633
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the correct file path
file_path = "E:/UE Sose2024/Projects/Data Science and Business/Assignment/XL partners all/Partners all 2023-2017 XL.xlsx"

# List of columns to read
columns_to_read = [
    'Period', 'ReporterDesc', 'PartnerDesc', 'CmdCode', 'QtyUnitAbbr',
    'Qty', 'AltQtyUnitAbbr', 'AltQty', 'NetWgt', 'PrimaryValue'
]

# Load the specified columns from the Excel file
data = pd.read_excel(file_path, usecols=columns_to_read)

# Convert AltQty from grams to kilograms where AltQtyUnitAbbr is 'g'
mask = data['AltQtyUnitAbbr'] == 'g'
data.loc[mask, 'AltQty'] = data.loc[mask, 'AltQty'] / 1000
data.loc[mask, 'AltQtyUnitAbbr'] = 'kg'

# Convert PrimaryValue to millions
data['PrimaryValue'] = data['PrimaryValue'] / 1e6

# Sort the DataFrame by ReporterDesc, Period, CmdCode, and PartnerDesc
sorted_data = data.sort_values(by=['ReporterDesc', 'Period', 'CmdCode', 'PartnerDesc'])

# Remove the QtyUnitAbbr and AltQtyUnitAbbr columns
sorted_data = sorted_data.drop(columns=['QtyUnitAbbr', 'AltQtyUnitAbbr'])

# Rename the PrimaryValue column to indicate the unit is in millions
sorted_data = sorted_data.rename(columns={'PrimaryValue': 'PrimaryValue (millions)'})

# Filter data for Togo and Zimbabwe
togo_data = sorted_data[sorted_data['ReporterDesc'] == 'Togo']
zimbabwe_data = sorted_data[sorted_data['ReporterDesc'] == 'Zimbabwe']

# Function to calculate descriptive statistics
def descriptive_stats(df, group_by_cols):
    stats = df.groupby(group_by_cols).agg({
        'Qty': ['mean', 'median', 'std', 'min', 'max'],
        'AltQty': ['mean', 'median', 'std', 'min', 'max'],
        'NetWgt': ['mean', 'median', 'std', 'min', 'max'],
        'PrimaryValue (millions)': ['mean', 'median', 'std', 'min', 'max']
    }).reset_index()
    return stats

# Calculate descriptive statistics for Togo and Zimbabwe
togo_stats = descriptive_stats(togo_data, ['PartnerDesc', 'CmdCode'])
zimbabwe_stats = descriptive_stats(zimbabwe_data, ['PartnerDesc', 'CmdCode'])

# Display statistics
print("Togo Descriptive Statistics:")
print(togo_stats)

print("\nZimbabwe Descriptive Statistics:")
print(zimbabwe_stats)

# Function to plot descriptive statistics
def plot_stats(df, country):
    fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20, 15))
    fig.suptitle(f'Descriptive Statistics for {country}', fontsize=16)

    df.plot(kind='bar', x='PartnerDesc', y=('Qty', 'mean'), ax=axes[0, 0], title='Mean Qty')
    df.plot(kind='bar', x='PartnerDesc', y=('AltQty', 'mean'), ax=axes[0, 1], title='Mean AltQty')
    df.plot(kind='bar', x='PartnerDesc', y=('NetWgt', 'mean'), ax=axes[1, 0], title='Mean NetWgt')
    df.plot(kind='bar', x='PartnerDesc', y=('PrimaryValue (millions)', 'mean'), ax=axes[1, 1], title='Mean PrimaryValue (millions)')

    plt.tight_layout()
    plt.show()

# Plot statistics for Togo and Zimbabwe
plot_stats(togo_stats, 'Togo')
plot_stats(zimbabwe_stats, 'Zimbabwe')
# Out:
# Togo Descriptive Statistics:
#              PartnerDesc CmdCode           Qty                                 \
#                                           mean   median          std      min
# 0                Belgium    7108    205.000000    205.0          NaN    205.0
# 1                Belgium  710812    205.000000    205.0          NaN    205.0
# 2                Lebanon    7108   3743.000000   3743.0  1346.331311   2791.0
# 3                Lebanon  710812   3743.000000   3743.0  1346.331311   2791.0
# 4        Other Asia, nes    7108      1.000000      1.0          NaN      1.0
# 5        Other Asia, nes  710813      1.000000      1.0          NaN      1.0
# 6   United Arab Emirates    7108   5587.250000   3543.0  7262.741786      1.0
# 7   United Arab Emirates  710812  11173.000000  11173.0  5782.719257   7084.0
# 8   United Arab Emirates  710813      1.500000      1.5     0.707107      1.0
# 9                  World    7108   6008.200000      2.0  8935.825631      1.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import FileLink, display
import os

# Define the correct file path
file_path = "E:/UE Sose2024/Projects/Data Science and Business/Assignment/XL partners all/Partners all 2023-2017 XL.xlsx"

# List of columns to read
columns_to_read = [
    'Period', 'ReporterDesc', 'PartnerDesc', 'CmdCode', 'QtyUnitAbbr',
    'Qty', 'AltQtyUnitAbbr', 'AltQty', 'NetWgt', 'PrimaryValue'
]

# Load the specified columns from the Excel file
data = pd.read_excel(file_path, usecols=columns_to_read)

# Convert AltQty from grams to kilograms where AltQtyUnitAbbr is 'g'
mask = data['AltQtyUnitAbbr'] == 'g'
data.loc[mask, 'AltQty'] = data.loc[mask, 'AltQty'] / 1000
data.loc[mask, 'AltQtyUnitAbbr'] = 'kg'

# Convert PrimaryValue to millions
data['PrimaryValue'] = data['PrimaryValue'] / 1e6

# Sort the DataFrame by ReporterDesc, Period, CmdCode, and PartnerDesc
sorted_data = data.sort_values(by=['ReporterDesc', 'Period', 'CmdCode', 'PartnerDesc'])

# Remove the QtyUnitAbbr and AltQtyUnitAbbr columns
sorted_data = sorted_data.drop(columns=['QtyUnitAbbr', 'AltQtyUnitAbbr'])

# Rename the PrimaryValue column to indicate the unit is in millions
sorted_data = sorted_data.rename(columns={'PrimaryValue': 'PrimaryValue (millions)'})

# Filter data for Togo and Zimbabwe
togo_data = sorted_data[sorted_data['ReporterDesc'] == 'Togo']
zimbabwe_data = sorted_data[sorted_data['ReporterDesc'] == 'Zimbabwe']

# Function to calculate descriptive statistics
def descriptive_stats(df, group_by_cols):
    stats = df.groupby(group_by_cols).agg({
        'Qty': ['mean', 'median', 'std', 'min', 'max'],
        'AltQty': ['mean', 'median', 'std', 'min', 'max'],
        'NetWgt': ['mean', 'median', 'std', 'min', 'max'],
        'PrimaryValue (millions)': ['mean', 'median', 'std', 'min', 'max']
    }).reset_index()
    # Flatten MultiIndex columns
    stats.columns = [' '.join(col).strip() for col in stats.columns.values]
    return stats

# Calculate descriptive statistics for Togo and Zimbabwe
togo_stats = descriptive_stats(togo_data, ['PartnerDesc', 'CmdCode'])
zimbabwe_stats = descriptive_stats(zimbabwe_data, ['PartnerDesc', 'CmdCode'])

# Display statistics
print("Togo Descriptive Statistics:")
print(togo_stats)

print("\nZimbabwe Descriptive Statistics:")
print(zimbabwe_stats)

# Save statistics to an Excel file in the current directory
output_file_path = os.path.join(os.getcwd(), "Descriptive_Statistics_Togo_Zimbabwe.xlsx")
with pd.ExcelWriter(output_file_path, engine='openpyxl') as writer:
    togo_stats.to_excel(writer, sheet_name='Togo Stats', index=False)
    zimbabwe_stats.to_excel(writer, sheet_name='Zimbabwe Stats', index=False)

# Check if the file was created
if os.path.exists(output_file_path):
    print(f"Descriptive statistics saved to {output_file_path}")
    # Provide a link to download the file
    display(FileLink(output_file_path))
else:
    print(f"Failed to save the file at {output_file_path}")

# Function to plot descriptive statistics
def plot_stats(df, country):
    fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20, 15))
    fig.suptitle(f'Descriptive Statistics for {country}', fontsize=16)

    df.plot(kind='bar', x='PartnerDesc', y='Qty mean', ax=axes[0, 0], title='Mean Qty')
    df.plot(kind='bar', x='PartnerDesc', y='AltQty mean', ax=axes[0, 1], title='Mean AltQty')
    df.plot(kind='bar', x='PartnerDesc', y='NetWgt mean', ax=axes[1, 0], title='Mean NetWgt')
    df.plot(kind='bar', x='PartnerDesc', y='PrimaryValue (millions) mean', ax=axes[1, 1], title='Mean PrimaryValue (millions)')

    plt.tight_layout()
    plt.show()

# Plot statistics for Togo and Zimbabwe
plot_stats(togo_stats, 'Togo')
plot_stats(zimbabwe_stats, 'Zimbabwe')
# Out:
# Togo Descriptive Statistics:
#              PartnerDesc  CmdCode      Qty mean  Qty median      Qty std  \
# 0                Belgium     7108    205.000000       205.0          NaN
# 1                Belgium   710812    205.000000       205.0          NaN
# 2                Lebanon     7108   3743.000000      3743.0  1346.331311
# 3                Lebanon   710812   3743.000000      3743.0  1346.331311
# 4        Other Asia, nes     7108      1.000000         1.0          NaN
# 5        Other Asia, nes   710813      1.000000         1.0          NaN
# 6   United Arab Emirates     7108   5587.250000      3543.0  7262.741786
# 7   United Arab Emirates   710812  11173.000000     11173.0  5782.719257
# 8   United Arab Emirates   710813      1.500000         1.5     0.707107
# 9                  World     7108   6008.200000         2.0  8935.825631
# 10                 World   710812  15018.500000     15018.5  6984.093678
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import FileLink, display
import openpyxl
from openpyxl.utils.dataframe import dataframe_to_rows
from openpyxl.drawing.image import Image
import os

# Define the correct file path
file_path = "E:/UE Sose2024/Projects/Data Science and Business/Assignment/XL partners all/Partners all 2023-2017 XL.xlsx"

# List of columns to read
columns_to_read = [
    'Period', 'ReporterDesc', 'PartnerDesc', 'CmdCode', 'QtyUnitAbbr',
    'Qty', 'AltQtyUnitAbbr', 'AltQty', 'NetWgt', 'PrimaryValue'
]

# Load the specified columns from the Excel file
data = pd.read_excel(file_path, usecols=columns_to_read)

# Convert AltQty from grams to kilograms where AltQtyUnitAbbr is 'g'
mask = data['AltQtyUnitAbbr'] == 'g'
data.loc[mask, 'AltQty'] = data.loc[mask, 'AltQty'] / 1000
data.loc[mask, 'AltQtyUnitAbbr'] = 'kg'

# Convert PrimaryValue to millions
data['PrimaryValue'] = data['PrimaryValue'] / 1e6

# Sort the DataFrame by ReporterDesc, Period, CmdCode, and PartnerDesc
sorted_data = data.sort_values(by=['ReporterDesc', 'Period', 'CmdCode', 'PartnerDesc'])

# Remove the QtyUnitAbbr and AltQtyUnitAbbr columns
sorted_data = sorted_data.drop(columns=['QtyUnitAbbr', 'AltQtyUnitAbbr'])

# Rename the PrimaryValue column to indicate the unit is in millions
sorted_data = sorted_data.rename(columns={'PrimaryValue': 'PrimaryValue (millions)'})

# Filter data for Togo and Zimbabwe
togo_data = sorted_data[sorted_data['ReporterDesc'] == 'Togo']
zimbabwe_data = sorted_data[sorted_data['ReporterDesc'] == 'Zimbabwe']

# Function to calculate descriptive statistics
def descriptive_stats(df, group_by_cols):
    stats = df.groupby(group_by_cols).agg({
        'Qty': ['mean', 'median', 'std', 'min', 'max'],
        'AltQty': ['mean', 'median', 'std', 'min', 'max'],
        'NetWgt': ['mean', 'median', 'std', 'min', 'max'],
        'PrimaryValue (millions)': ['mean', 'median', 'std', 'min', 'max']
    }).reset_index()
    # Flatten MultiIndex columns
    stats.columns = [' '.join(col).strip() for col in stats.columns.values]
    return stats

# Calculate descriptive statistics for Togo and Zimbabwe
togo_stats = descriptive_stats(togo_data, ['PartnerDesc', 'CmdCode'])
zimbabwe_stats = descriptive_stats(zimbabwe_data, ['PartnerDesc', 'CmdCode'])

# Display statistics
print("Togo Descriptive Statistics:")
print(togo_stats)

print("\nZimbabwe Descriptive Statistics:")
print(zimbabwe_stats)

# Function to save statistics and plots in the same Excel sheet
def save_stats_and_plots(togo_stats, zimbabwe_stats, output_file_path):
    with pd.ExcelWriter(output_file_path, engine='openpyxl') as writer:
        workbook = writer.book
        sheet = workbook.create_sheet(title="Descriptive Statistics")
        
        # Write statistics to the sheet
        start_row = 1
        
        for stats, country in [(togo_stats, 'Togo'), (zimbabwe_stats, 'Zimbabwe')]:
            for metric in ['Qty', 'AltQty', 'NetWgt', 'PrimaryValue (millions)']:
                sheet.cell(row=start_row, column=1, value=f"{country} {metric} Statistics")
                metric_stats = stats[['PartnerDesc', 'CmdCode', f'{metric} mean', f'{metric} median', f'{metric} std', f'{metric} min', f'{metric} max']]
                for r_idx, row in enumerate(dataframe_to_rows(metric_stats, index=False, header=True)):
                    for c_idx, value in enumerate(row, 1):
                        sheet.cell(row=start_row + r_idx + 1, column=c_idx, value=value)
                start_row += len(metric_stats) + 3
                
                # Generate plot for each metric
                plt.figure(figsize=(10, 6))
                metric_stats.plot(kind='bar', x='PartnerDesc', y=f'{metric} mean', title=f'{country} {metric} Mean')
                plot_path = f"{country}_{metric}_mean_plot.png"
                plt.savefig(plot_path)
                plt.close()
                
                # Insert plot into Excel sheet
                img = Image(plot_path)
                img.anchor = f"A{start_row}"
                sheet.add_image(img)
                start_row += 20
        
        # Add a report summary
        report_text = """Report Summary:
        This analysis provides descriptive statistics for the trade data of Togo and Zimbabwe from 2017 to 2023.
        Each metric (Qty, AltQty, NetWgt, PrimaryValue) is analyzed separately, showing mean, median, standard deviation, minimum, and maximum values.
        The corresponding plots are included for better visualization.
        """
        sheet.cell(row=start_row, column=1, value=report_text)
    
    print(f"Descriptive statistics and plots saved to {output_file_path}")

# Save statistics and plots in the same Excel sheet
output_file_path = os.path.join(os.getcwd(), "Descriptive_Statistics_Togo_Zimbabwe.xlsx")
save_stats_and_plots(togo_stats, zimbabwe_stats, output_file_path)

# Check if the file was created
if os.path.exists(output_file_path):
    print(f"Descriptive statistics saved to {output_file_path}")
    # Provide a link to download the file
    display(FileLink(output_file_path))
else:
    print(f"Failed to save the file at {output_file_path}")
# Out:
# Togo Descriptive Statistics:
#              PartnerDesc  CmdCode      Qty mean  Qty median      Qty std  \
# 0                Belgium     7108    205.000000       205.0          NaN
# 1                Belgium   710812    205.000000       205.0          NaN
# 2                Lebanon     7108   3743.000000      3743.0  1346.331311
# 3                Lebanon   710812   3743.000000      3743.0  1346.331311
# 4        Other Asia, nes     7108      1.000000         1.0          NaN
# 5        Other Asia, nes   710813      1.000000         1.0          NaN
# 6   United Arab Emirates     7108   5587.250000      3543.0  7262.741786
# 7   United Arab Emirates   710812  11173.000000     11173.0  5782.719257
# 8   United Arab Emirates   710813      1.500000         1.5     0.707107
# 9                  World     7108   6008.200000         2.0  8935.825631
# 10                 World   710812  15018.500000     15018.5  6984.093678
# ...
